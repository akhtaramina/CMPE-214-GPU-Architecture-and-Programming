# %% [markdown]
# <a href="https://colab.research.google.com/github/akhtaramina/CMPE-214-GPU-Architecture-and-Programming/blob/main/labs/lab1/214Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !bash
# Out:
# bash: cannot set terminal process group (676): Inappropriate ioctl for device
# bash: no job control in this shell
# /content# nvcc --version
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0
# /content# gcc --version
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# /content# nvdia-smi
# bash: nvdia-smi: command not found
# /content# nvdia -smi
# bash: nvdia: command not found
# /content# nvidia-smi
# Wed Aug 26 18:22:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# ...
